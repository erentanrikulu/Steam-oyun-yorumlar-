# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.stem import WordNetLemmatizer, PorterStemmer
from nltk.tokenize import word_tokenize

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\eren\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\eren\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\eren\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
df= pd.read_csv("stemmed_sentences.csv")

# %%
df
# Out:
#            elden ring first game ever gotten achiev amaz
# 0              best game ever play love everi minut play
# 1                               stori world charact love
# 2      felt like kid candyshop except storeown everyo...
# 3                                  yeah ca wait dlc come
# 4                                        game get golden
# ...                                                  ...
# 19308  black myth wukong noth short masterpiec action...
# 19309  moment step world captiv stun visual bring anc...
# 19310  combat incred fluid satisfi demand strategi sk...
# 19311  like black myth wukong gameplay stori tell enr...
# 19312  prime still bad mani cheater real elden ring f...
#
# [19313 rows x 1 columns]

# %%
df.columns = ["0"]

# NaN değerleri ve boş stringleri temizle
df = df.dropna()
df = df[df["0"].str.strip() != ""]

# Temizlenmiş ilk 5 cümleyi göster
print(df.head())
# Out:
#                                                    0
# 0          best game ever play love everi minut play
# 1                           stori world charact love
# 2  felt like kid candyshop except storeown everyo...
# 3                              yeah ca wait dlc come
# 4                                    game get golden

# %%
#Varsayalım ki DataFrame'iniz df ve yorumlar '0' sütununda
text = ' '.join(df['0'].astype(str).tolist())  # Tüm yorumları tek bir metin haline getir
sentences = sent_tokenize(text)  # Metni cümlelere ayır

# %%
# Stopwords listesini almak
stop_words = set(stopwords.words('english'))

# %%
from nltk.stem import WordNetLemmatizer, PorterStemmer
from nltk.tokenize import word_tokenize

# Lemmatizer ve Stemmer nesnelerini oluştur
lemmatizer = WordNetLemmatizer()
stemmer = PorterStemmer()
# Kelimeleri tokenleştirip, lemmatize etme ve stemleme
def preprocess_sentence(sentence):
    tokens = word_tokenize(sentence)
    filtered_tokens = [token.lower() for token in tokens if token.isalpha() and token.lower() not in stop_words]
    lemmatized_tokens = [lemmatizer.lemmatize(token) for token in filtered_tokens]
    stemmed_tokens = [stemmer.stem(token) for token in filtered_tokens]
    return lemmatized_tokens, stemmed_tokens

# Kullanım örneği
tokenized_corpus_lemmatized = []
tokenized_corpus_stemmed = []

for sentence in sentences:
    lemmatized_tokens, stemmed_tokens = preprocess_sentence(sentence)
    tokenized_corpus_lemmatized.append(lemmatized_tokens)
    tokenized_corpus_stemmed.append(stemmed_tokens)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# Ön işlenmiş token listelerini tekrar metne çeviriyoruz
lemmatized_texts = [' '.join(tokens) for tokens in tokenized_corpus_lemmatized]

lemmatized_texts[:3]
# Out:
# ['best game ever play love everi minut play stori world charact love felt like kid candyshop except storeown everyon shop tri kill keep dodg tri steal candi giggl wildli gone mad touch giant burn smolder hand three finger hey least get awesom look eye yeah ca wait dlc come game get golden blood gut friend guy ask realli one best game ever play emperor hochland trait knowledg trait mechan use good complet worthless know singl player game mildli overpow mechan take lot work take advantag allow also understand multiplay commun gamemod feel balanc stop bring overli balanc approach singl player care conquest mode multiplay stuff keep get ad understand obsess tri shoehorn coop game even done well one step forward two step start address eleph room hour game recommend well let breakdown hour hour duplic progress world section alreadi hour ride around open world fight enemi explor dungeon fight bos hour actual fun part game legaci dungeon area follow format previou soul game featur area interest enemi hour arena pvp invas overal make hour fun content hour filler plan buy game play friend prepar ratio fun filler content like get critic game world open world honestli realli beauti engag first area limgrav liurnia caelid abl explor intend hors play multiplay big deal first area good amount content pack see enemi varieti first time bore yet problem begin way game altu plateau area realli beauti well probabl favorit visual start notic realli empti area lot enemi open world get leyndel arriv worst part game mountaintop giant area think one singl new enemi previou area differ skin even worth word describ bad area buy game despit neg review advic hop hors ride straight bos noth worth explor right anoth empti snow area dev use innov trick area cover snowstorm expertli hide area time finish see devoid content first netcod game multiplay absolut trash connect friend fail hang time invad requir use item time success invad someon far anyon tell fromsoft basic still use netcod use back dark soul coupl bandaid thrown top prevent infinit backstab latenc huge decid everi fight lot skill come abl quickli identifi approxim ping differ oppon adapt tactic skill pve carri pve look enemi attack decid press dodg think hit pvp press dodg anyway matter weapon invis hitbox latenc top fromsoft decid make latenc issu even promin introduc power statu effect build even success dodg enemi attack top level pvp full scarlet rot sleep statu abus exploit fact statu effect build even dodg counter duplic item cheat cure middl combat oh want turn tactic around need duplic item sleep rot greas limit quantiti obtain legitim singl playthrough watch invas honestli make laugh mani item player pop like candi pvp laughabl top multiplay decis made develop describ anyth stupid first requir item even allow summon peopl earli game wast time farm flower probabl minut tri figur summon look next kill bos summon friend anymor invad area kill bos particular chunk whole area multiplay kill bos anywher world even random dragon sent home cooper random prevent enter cave friend disconnect ride spot world enter cave world friend logic right obvious improv gameplay even everyth work properli network issu get way elden ring horribl balanc first coupl bos everi challeng game start becom easi enemi simpli code well deal multipl player attack bos chang target anytim take damag even tini throw knife mean incred easi bos suppos abl kill damag punish tri heal alway abl heal unless mess horribl get kill singl combo happen bos still take tri differ multiplay singleplay despit fact game increas enemi health game least time easier tri compens friend turn taunter tongu attract invad game still easi incred hard invad fairli beat peopl tri invad probabl walk blender peopl spam spell ash war die second mean peopl left invad higher level peopl manag fun within framework player use tactic necessari win prepar deal lot duplic rot greas duplic starlight shard snipe across map duplic golem arrow nuke build kill mak ...

# %%
# TF-IDF vektörizerı başlatıyoruz
vectorizer = TfidfVectorizer()

# TF-IDF matrisini oluşturuyoruz
#terim frekansları, belge frekanslarıni hesplar
#TF-IDF vektörlerine dönüştürür
tfidf_matrix = vectorizer.fit_transform(lemmatized_texts)

## Kelimeleri alalım
#F-IDF vektörleştirme işleminde kullanılan tüm kelimelerin essiz bir listesini döndürur
feature_names = vectorizer.get_feature_names_out()

# TF-IDF matrisini pandas DataFrame'e çevir-gorunurluk acisindan- calismasi kolay
tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), columns=feature_names)

# İlk birkaç satırı gösterelim-ilk 5 cümle
print(tfidf_df.head())

#Her satır bir cümleyi temsil eder
#Her sütun bir kelimeyi temsil eder
#Hücreler ise o kelimenin o cümledeki TF-IDF skorudur - her cumle icin degisir-bakiniz:slaytlar
# Out:
#          aa       aaa  \
# 0  0.000578  0.003797
#
#    ...  \
# 0                                           0.000083
#
#    aaaaaaaaaaaaaaaaaaaaah  aaaaaaaaaaaaaareeeeeeeeeeeeetuuuuuuuuuu  \
# 0                0.000083                                 0.000083
#
#    aaaaaaaaaaaah  aaaaaaaaaaretu     aaand  aaannnnd      aand  ...     𝘎𝘳𝘦𝘢𝘵  \
# 0       0.000083        0.000083  0.000083  0.000083  0.000083  ...  0.000248
#
#          𝘣𝘺  𝘤𝘩𝘦𝘢𝘵𝘦𝘳𝘴      𝘨𝘢𝘮𝘦    𝘳𝘶𝘪𝘯𝘦𝘥     𝙂𝙧𝙚𝙖𝙩        𝙗𝙮  𝙘𝙤𝙢𝙢𝙪𝙣𝙞𝙩𝙮  \
# 0  0.000248  0.000248  0.000248  0.000248  0.000083  0.000083   0.000083
#
#        𝙜𝙖𝙢𝙚    𝙧𝙪𝙞𝙣𝙚𝙙
# 0  0.000083  0.000083
#
# [1 rows x 12342 columns]

# %%
tfidf_df.to_csv('tfidf_stemmed.csv', index=False)
